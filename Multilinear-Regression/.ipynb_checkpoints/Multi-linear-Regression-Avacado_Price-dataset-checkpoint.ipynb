# %% [markdown]
# # Multi-linear Regression - Avacado_Price dataset

# %% [raw]
# Problem Statement:
# With the growing consumption of avocados in the USA, a freelance company would like to do some analysis on the patterns of consumption in different cities and would like to come up with a prediction model for the price of avocados. For this to be implemented, build a prediction model using multilinear regression and provide your insights on it.

# %% [raw]
# **Business Problem:**
#
# The freelance company aims to analyze the patterns of avocado consumption across various cities in the USA and develop a predictive model for avocado prices. Avocado consumption has been steadily rising in the USA, and understanding the factors influencing avocado prices can aid businesses in forecasting and strategic decision-making related to avocado supply and demand.
#
# **Objective:**
#
# 1. Analyze avocado consumption patterns in different cities across the USA.
# 2. Develop a multilinear regression model to predict avocado prices based on various factors such as city demographics, consumption trends, transportation costs, etc.
# 3. Provide insights into the factors that significantly influence avocado prices.
# 4. Offer a reliable predictive tool to forecast avocado prices for businesses operating in the avocado supply chain.
#
# **Constraints:**
#
# 1. **Data Availability:** The availability and quality of data on avocado consumption, prices, and relevant factors may vary across different cities. Ensuring a comprehensive dataset from various sources is crucial for accurate analysis.
#
# 2. **Model Complexity:** While multilinear regression is a powerful tool, the model's complexity should be balanced to avoid overfitting. Careful feature selection and regularization techniques may be required.
#
# 3. **Assumptions:** The model's accuracy relies on the assumptions made about the relationship between avocado prices and the chosen predictors. Assumptions such as linearity, independence of errors, homoscedasticity, and normality should be validated.
#
# 4. **Interpretability:** The model should not only provide accurate predictions but also offer interpretable insights into the factors influencing avocado prices. Clear interpretation aids businesses in making informed decisions.
#
# 5. **External Factors:** External factors such as weather conditions, trade policies, and global avocado production can impact avocado prices. While these factors may not be directly controllable, their influence should be acknowledged and monitored.
#
# 6. **Ethical Considerations:** The analysis should adhere to ethical guidelines, ensuring fair treatment of data subjects and responsible handling of sensitive information.

# %% [raw]
# # Data Dictionary
# AveragePrice: This column likely represents the average price of avocados in a given region and year.
#
# Total_Volume: This column likely represents the total volume or quantity of avocados sold in the specified region and year.
#
# tot_ava1, tot_ava2, tot_ava3: These columns seem to represent different categories or types of avocados, possibly categorized based on quality, size, or variety.
#
# Total_Bags: This column likely represents the total number of bags of avocados sold.
#
# Small_Bags: This column likely represents the number of small bags of avocados sold.
#
# Large_Bags: This column likely represents the number of large bags of avocados sold.
#
# XLarge Bags: This column likely represents the number of extra-large bags of avocados sold.
#
# type: This column may indicate the type or category of avocados, such as conventional or organic.
#
# year: This column represents the year of the data.
#
# region: This column likely indicates the region or city where the avocados were sold.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\delll\Desktop\Python\DataSets\Datasets_MLR\Avacado_Price.csv")
df.head()
# Out:
#    AveragePrice  Total_Volume  tot_ava1   tot_ava2  tot_ava3  Total_Bags  \
# 0          1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1          1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2          0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3          1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4          1.28      51039.60    941.48   43838.39     75.78     6183.95
#
#    Small_Bags  Large_Bags  XLarge Bags          type  year  region
# 0     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5677.40      133.76          0.0  conventional  2015  Albany
# 4     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.shape
# rows=18249 and columns=12
# Out:
# (18249, 12)

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total_Volume', 'tot_ava1', 'tot_ava2', 'tot_ava3',
#        'Total_Bags', 'Small_Bags', 'Large_Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total_Volume    float64
# tot_ava1        float64
# tot_ava2        float64
# tot_ava3        float64
# Total_Bags      float64
# Small_Bags      float64
# Large_Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total_Volume  18249 non-null  float64
#  2   tot_ava1      18249 non-null  float64
#  3   tot_ava2      18249 non-null  float64
#  4   tot_ava3      18249 non-null  float64
#  5   Total_Bags    18249 non-null  float64
#  6   Small_Bags    18249 non-null  float64
#  7   Large_Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df.isnull().sum()
# Out:
# AveragePrice    0
# Total_Volume    0
# tot_ava1        0
# tot_ava2        0
# tot_ava3        0
# Total_Bags      0
# Small_Bags      0
# Large_Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.describe()
# Out:
#        AveragePrice  Total_Volume      tot_ava1      tot_ava2      tot_ava3  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total_Bags    Small_Bags    Large_Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
df.describe(include="object")
# Out:
#                 type  region
# count          18249   18249
# unique             2      54
# top     conventional  Albany
# freq            9126     338

# %%
print(df["type"].value_counts())
sns.countplot(x=df["type"])
plt.show()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
i=1
cols=['AveragePrice',
 'Total_Volume',
 'tot_ava1',
 'tot_ava2',
 'tot_ava3',
 'Total_Bags',
 'Small_Bags',
 'Large_Bags',
 'XLarge Bags']
plt.figure(figsize=(16,13))
for col in cols:
    plt.subplot(3,4,i)
    sns.boxplot(df[col])
    plt.title(col)
    i=i+1

# %%
list(df.describe().columns)
# Out:
# ['AveragePrice',
#  'Total_Volume',
#  'tot_ava1',
#  'tot_ava2',
#  'tot_ava3',
#  'Total_Bags',
#  'Small_Bags',
#  'Large_Bags',
#  'XLarge Bags',
#  'year']

# %%
from feature_engine.outliers import Winsorizer
for col in cols:
    winsor=Winsorizer(capping_method="iqr",fold=1.5,variables=col,tail="both")
    df[col]=winsor.fit_transform(df[[col]])

# %%
i=1
plt.figure(figsize=(16,13))
for col in cols:
    plt.subplot(3,4,i)
    sns.boxplot(df[col])
    plt.title(col)
    i=i+1
# outliers are removed

# %%
i=1
plt.figure(figsize=(16,13))
for col in cols:
    plt.subplot(3,4,i)
    sns.distplot(df[col])
    i=i+1
