# %% [markdown]
# # Simple Linear Regression- SAT-GPA dataset

# %% [raw]
# Problem Statement:
#
# A certain university wants to understand the relationship between students’ SAT scores and their GPA. Build a Simple Linear Regression model with GPA as the target variable and record the RMSE and correlation coefficient values for different models.

# %% [raw]
# ** Business Problem:
#
# A university seeks to analyze the correlation between students' SAT scores and their Grade Point Average (GPA) to gain insights into academic performance predictors.
#
# ** Objectives:
#
# 1. To Develop a Simple Linear Regression model to predict GPA based on SAT scores.
# 2. To Determine the strength and direction of the relationship between SAT scores and GPA.
# 3. To predictive power of SAT scores on students' academic performance.
#
# ** Constraints:
#
# 1. Availability of accurate and reliable data on students' SAT scores and GPA.
#
# 2. Ensure compliance with privacy regulations and ethical considerations when handling student data.
#
# 3. Maintain transparency in the model-building process and communicate findings effectively to stakeholders.
#
# 4. Consider potential confounding variables that may influence GPA, such as socioeconomic background or extracurricular activities.
#
# 5. Strive for a model that is interpretable and easy to understand for non-technical stakeholders, such as university administrators and faculty members.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("C:\\Users\\delll\\Desktop\\Python\\DataSets\\SAT_GPA.csv")
df.head()
# Out:
#    SAT_Scores  GPA
# 0         206  2.3
# 1         214  2.4
# 2         717  3.5
# 3         580  2.8
# 4         404  2.6

# %%
df.shape
# Out:
# (200, 2)

# %%
df.columns
# Out:
# Index(['SAT_Scores', 'GPA'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SAT_Scores  200 non-null    int64
#  1   GPA         200 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 3.2 KB

# %%
df.describe()
# The average SAT_Scores is 491.81,minimum is 202 and maximum is 797.
# The average GPA of student is 2.85,minimum is 2 and maximum is 3.9 .

# %% [markdown]
# ### Univariate analysis

# %%
# draw histogram for SAT_Scores
sns.distplot(df["SAT_Scores"])
plt.show()
# data is slightly normally distributed

# %%
# draw histogram for GPA
sns.distplot(df["GPA"])
plt.show()
# data is slightly normally distributed

# %%
sns.boxplot(df["SAT_Scores"])
plt.show()
# no outliers are present

# %%
sns.boxplot(df["GPA"])
plt.show()
# no outliers are present

# %%
# draw scatter plot for YearsExperience vs Salary
sns.scatterplot(x=df["SAT_Scores"],y=df["GPA"],color="g")
plt.show()
# from graph we can see that there is no relationship between the columns

# %%
# draw pairplot for dataframe
sns.pairplot(df)
plt.show()

# %%
sns.heatmap(df.corr(),cmap="coolwarm",annot=True,fmt="0.02f")
plt.show()
# from this graph that both columns have weak positive correlation with each other.

# %%
x_train,x_test,y_train,y_test=train_test_split(df[["SAT_Scores"]],df["GPA"],test_size=0.2)

# %%
x_train.shape
# Out:
# (160, 1)

# %%
x_test.shape
# Out:
# (40, 1)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mse=mean_squared_error(y_test, y_pred)
r2=r2_score(y_test, y_pred)
print('MSE:',mse)
print('R2 score:',r2)
# Out:
# MSE: 0.3545535861832979
# R2 score: 0.015402426594562924

# %%
#Visualize the result
plt.scatter(x_test,y_test,color='b',label='Actual')
plt.plot(x_test,y_pred,color='r',label='Predicted')
plt.title('Simple Linear Regression')
plt.xlabel("Sat Scores")
plt.ylabel("GPA")
plt.legend()
plt.show()
